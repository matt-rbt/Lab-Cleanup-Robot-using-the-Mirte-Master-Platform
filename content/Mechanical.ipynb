# %% [markdown]
# # Mechancal modifications
#
# efore the Mirte Master can be used for this application, some modifications needed to be made to the chassis.

# %%
from IPython.display import HTML

HTML("""
<script type="module" src="https://unpkg.com/@google/model-viewer/dist/model-viewer.min.js"></script>

<model-viewer
    src="models/mirte_master.glb"
    camera-controls
    auto-rotate
    style="width: 800px; height: 600px; background: #d1d9e6;">
</model-viewer>
""")
# Out:
# <script type="module" src="https://unpkg.com/@google/model-viewer/dist/model-viewer.min.js"></script>
#
# <model-viewer
#     src="models/mirte_master.glb"
#     camera-controls
#     auto-rotate
#     style="width: 800px; height: 600px; background: #d1d9e6;">
# </model-viewer>
