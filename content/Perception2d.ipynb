# %% [markdown]
# # Perception 2D
#
# For determening the type, and possibly, the distance of objects we use a YOLO26 object classification model. We made our own dataset by recording video using the USB Camera included in the MIRTE Master hardware package. After recording the video we extracted one in every fifteen frames to use for our training dataset. A picture of 4 frames in different environments is shown below
#
# ```{figure} https://github.com/matt-rbt/Lab-Cleanup-Robot-using-the-Mirte-Master-Platform/blob/main/content/figures/trainingdataset.png
# :label: fig_trainingdataset
# :width: 70%
# :align: center
#
# Picture of 4 individual frames
# ```
# ## Why was YOLO26 used
#
# The YOLO object-detection family is well established, with YOLO26 being the most recent generation. YOLO26 was chosen because our robot has to detect and classify objects from a live camera on the MIRTE Master platform, which has limited processing power because it uses a OrangePi 3B. Object detection with limited processing power requires a lightweight model with fast inference times while still maintaining accuracy. YOLO26 is suitable for this because it was designed with deployment on low-power devices in mind. YOLO26 changed the post-processing pipeline to NMS-free inference, simplified bounding-box predictions and supports deployment formats commonly used for low-power devices [@yolo26keyarchitecturalenhancements], in our case, the RK3566 NPU of the OrangePi 3B can be used for improving the performance, reducing the total inference time [@Yolo11RK3566]. For our model, we chose to use the Nano variant of YOLO26 to minimize inference times. Another benefit of the newer YOLO26 variant over the older variants is that YOLO26 allows for oriented bounding boxes. Unlike standard bouhnding boxes, oriented bounding boxes also estimate the rotation of recognized objects [@2026ultralyticsyoloevolutionoverview]. This could be useful for complex grasping tasks where orientation of the gripper is crucial. However, this project only uses standard object detection.
#
# ## Training and Results
# Training was done manually using Label Studio. Inittially, ~280 frames were captured in 4 different environments. Due to a large amount of blurring in the images, about 100 pictures were deleted. Of the remaining 180 pictures, 60 pictures were imported into Label Studio and labelled per colour: Green, Red, Purple, White, Light grey, Dark grey, and Black. In total 1206 bounding boxes were drawn. The relevant results of the training session are shown below.
#
# ```{figure} https://github.com/matt-rbt/Lab-Cleanup-Robot-using-the-Mirte-Master-Platform/blob/main/content/figures/val_batch0_pred.jpg
# :label: fig_trainingdatasetresults
# :width: 70%
# :align: center
#
# Picture of tests performed during training
# ```
# ```{figure} https://github.com/matt-rbt/Lab-Cleanup-Robot-using-the-Mirte-Master-Platform/blob/main/content/figures/results.png
# :label: fig_trainingdatasetplots
# :width: 70%
# :align: center
#
# Plots of trainingresults per epoch.
# ```
# ```{figure} https://github.com/matt-rbt/Lab-Cleanup-Robot-using-the-Mirte-Master-Platform/blob/main/content/figures/confusion_matrix_normalized.png
# :label: fig_trainingdatasetplots
# :width: 70%
# :align: center
#
# Normalized confusion matrix: Most classes are classified correctly, as indicated by the strong diagonal values. Some of objects were missed as background, a small amount of objects were mis-classified, and some objects were recognized while they should not.
# ```
# ```{figure} https://github.com/matt-rbt/Lab-Cleanup-Robot-using-the-Mirte-Master-Platform/blob/main/content/figures/BoxF1_curve.png
# :label: fig_trainingdatasetplots
# :width: 70%
# :align: center
#
# BoxF1 curve: shows us at detection performance for each confidence level per each object type. A good starting confidence threshold would be 0.3-0.35.
# ```
